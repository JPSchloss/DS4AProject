# %% [markdown]
# # Billboard Script

# %%
import pandas as pd
import numpy as np 
import billboard 
import json
from IPython.display import IFrame

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import config as config

cid = config.spotify_api['id']
secret = config.spotify_api['secret']

client_credentials_manager = SpotifyClientCredentials(client_id = cid, client_secret = secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Run in Terminal
# pip install billboard.py  
# pip install spotipy

# %% [markdown]
# ### Getting Charts

# %%
# Available Current Charts
billboard.charts()
# Out:
# ['hot-100',
#  'billboard-200',
#  'artist-100',
#  'social-50',
#  'streaming-songs',
#  'radio-songs',
#  'digital-song-sales',
#  'top-album-sales',
#  'current-albums',
#  'catalog-albums',
#  'independent-albums',
#  'soundtracks',
#  'vinyl-albums',
#  'billboard-global-200',
#  'billboard-global-excl-us',
#  'greatest-billboard-200-albums',
#  'greatest-billboard-200-artists',
#  'greatest-hot-100-singles',
#  'greatest-hot-100-artists',
#  'greatest-hot-100-songs-by-women',
#  'greatest-hot-100-women-artists',
#  'greatest-billboard-200-albums-by-women',
#  'greatest-billboard-200-women-artists',
#  'greatest-billboards-top-songs-80s',
#  'greatest-billboards-top-songs-90s',
#  'greatest-of-all-time-pop-songs',
#  'greatest-of-all-time-pop-songs-artists',
#  'greatest-adult-pop-songs',
#  'greatest-adult-pop-artists',
#  'greatest-country-songs',
#  'greatest-country-albums',
#  'greatest-country-artists',
#  'greatest-of-all-time-latin-artists',
# ...

# %%
# Available Year End Charts
billboard.charts(year_end=True)
# Out:
# ['top-artists',
#  'top-artists-duo-group',
#  'top-artists-female',
#  'top-artists-male',
#  'top-new-artists',
#  'labels',
#  'hot-100-artists',
#  'hot-100-songs',
#  'hot-100-artists-duo-group',
#  'hot-100-artists-female',
#  'hot-100-artists-male',
#  'hot-100-imprints',
#  'hot-100-labels',
#  'hot-100-producers',
#  'top-billboard-200-artists',
#  'top-billboard-200-albums',
#  'the-billboard-200-artists-duo-group',
#  'the-billboard-200-artists-female',
#  'the-billboard-200-artists-male',
#  'the-billboard-200-imprints',
#  'the-billboard-200-labels',
#  'the-billboard-200-distributors',
#  'streaming-songs-artists',
#  'streaming-songs',
#  'streaming-songs-labels',
#  'on-demand-songs-artists',
#  'on-demand-songs',
#  'radio-songs-artists',
#  'radio-songs',
#  'radio-songs-labels',
#  'digital-songs-artists',
#  'digital-songs',
#  'hot-digital-songs-imprints',
#  'hot-digital-songs-labels',
#  'social-50-artists',
#  'independent-artists',
#  'independent-albums',
# ...

# %%
Top_Track_Charts = ['hot-100', 'billboard-200','streaming-songs',
                    'digital-song-sales', 'billboard-global-200', 'billboard-global-excl-us',
                    'pop-songs','adult-contemporary', 'adult-pop-songs', 'country-songs', 
                    'country-streaming-songs', 'country-digital-song-sales', 'rock-songs', 
                    'rock-streaming-songs', 'rock-streaming-songs', 'rock-digital-song-sales', 
                    'hot-alternative-songs', 'alternative-streaming-songs', 'alternative-digital-song-sales',
                    'hot-hard-rock-songs', 'hard-rock-streaming-songs','hard-rock-digital-song-sales', 
                    'hot-mainstream-rock-tracks', 'r-b-hip-hop-songs', 'r-and-b-hip-hop-streaming-songs', 
                    'r-and-b-hip-hop-digital-song-sales', 'r-and-b-songs', 'r-and-b-streaming-songs',
                    'r-and-b-digital-song-sales', 'rap-song', 'rap-streaming-songs', 'hot-rap-tracks',
                    'rap-digital-song-sales', 'mainstream-r-and-b-hip-hop', 'rhythmic-40', 'latin-songs', 
                    'latin-streaming-songs', 'latin-digital-song-sales', 'dance-electronic-songs', 
                    'dance-electronic-streaming-songs', 'dance-electronic-digital-song-sales', 
                    'dance-club-play-songs', 'christian-songs', 'christian-streaming-songs', 
                    'christian-digital-song-sales', 'hot-christian-adult-contemporary',
                    'gospel-songs', 'gospel-digital-song-sales', 'contemporary-jazz', 'jazz-songs', 
                    'top-triller-global', 'top-triller-us', 'hot-holiday-songs', 'holiday-streaming-songs',
                    'holiday-songs', 'holiday-season-digital-song-sales', 'summer-songs', 'canadian-hot-100', 
                    'hot-canada-digital-song-sales', 'canada-ac', 'canada-chr-top-40', 'canada-country',
                    'canada-hot-ac', 'canada-rock', 'mexico', 'mexico-ingles', 'mexico-popular', 
                    'mexico-espanol', 'japan-hot-100', 'billboard-korea-100', 'billboard-argentina-hot-100',
                    'official-uk-songs', 'uk-digital-song-sales', 'euro-digital-song-sales', 
                    'france-digital-song-sales', 'germany-songs', 'italy-digital-song-sales',
                    'spain-digital-song-sales', 'switzerland-digital-song-sales', 
                    'australia-digital-song-sales', 'bubbling-under-hot-100-singles', 'world-digital-song-sales'] 


Artists_Charts = ['artist-100','social-50', 'emerging-artists', 'next-big-sound-25', 'canada-emerging-artists'] 

Album_Charts = ['top-album-sales','current-albums', 'catalog-albums', 'independent-albums',
                'soundtracks', 'vinyl-albums','country-albums', 'bluegrass-albums', 
                'americana-folk-albums', 'rock-albums','alternative-albums', 'hard-rock-albums', 
                'r-b-hip-hop-albums', 'r-and-b-albums', 'latin-albums', 'regional-mexican-albums', 
                'latin-pop-albums', 'tropical-albums', 'latin-rhythm-albums', 
                'dance-electronic-albums', 'christian-albums', 'classical-albums', 
                'classical-crossover-albums', 'traditional-classic-albums', 'jazz-albums', 
                'traditional-jazz-albums', 'heatseekers-albums', 'holiday-albums', 
                'canadian-albums', 'official-uk-albums', 'german-albums', 'greece-albums',
                'italy-albums', 'australian-albums', 'blues-albums', 'cast-albums',
                'comedy-albums', 'compilation-albums', 'kids-albums', 'new-age-albums',
                'reggae-albums', 'tastemaker-albums', 'world-albums']






Tracks_Charts_EndYear = ['hot-100-songs', 'streaming-songs', 'on-demand-songs', 'radio-songs', 
                      'digital-songs', 'pop-songs', 'adult-contemporary-songs', 'hot-country-songs', 
                      'country-airplay-songs','country-digital-songs', 'country-streaming-songs', 
                      'hot-rock-songs','rock-airplay-songs', 'rock-digital-songs',  'rock-streaming-songs', 
                      'alternative-songs', 'alternative-digital-song-sales-yearend', 
                      'hot-r-and-and-b-hip-hop-songs', 'r-and-b-hip-hop-airplay-songs', 
                      'r-and-b-hip-hop-digital-songs', 'r-and-b-hip-hop-streaming-songs', 
                      'hot-r-and-and-b-songs', 'r-and-b-digital-songs', 'r-and-b-streaming-songs', 
                      'hot-rap-songs', 'rap-airplay-songs','rap-digital-songs', 'rap-streaming-songs',
                      'rhythmic-songs', 'hot-latin-songs', 'latin-digital-songs', 'latin-streaming-songs', 
                      'latin-airplay-songs', 'latin-pop-airplay-songs', 'regional-mexican-airplay-songs',
                      'canadian-hot-100','music-video-sales','smooth-jazz-songs','gospel-streaming-songs',
                      'gospel-digital-songs','hot-gospel-songs','christian-streaming-songs',
                      'hot-christian-adult-contemporary', 'christian-digital-songs', 'hot-christian-songs',
                      'dance-electronic-streaming-songs','dance-electronic-digital-songs','dance-electronic-streaming-songs',
                      'dance-electronic-digital-songs','hot-dance-electronic-songs'] 

Artists_Charts_EndYear = ['hot-100-songs', 'streaming-songs', 'on-demand-songs', 'radio-songs', 
                          'digital-songs', 'pop-songs', 'adult-contemporary-songs', 'hot-country-songs', 
                          'country-airplay-songs','country-digital-songs', 'country-streaming-songs', 
                          'hot-rock-songs','rock-airplay-songs', 'rock-digital-songs',  'rock-streaming-songs',
                          'alternative-songs', 'alternative-digital-song-sales-yearend', 
                          'hot-r-and-and-b-hip-hop-songs', 'r-and-b-hip-hop-airplay-songs', 
                          'r-and-b-hip-hop-digital-songs', 'r-and-b-hip-hop-streaming-songs', 
                          'hot-r-and-and-b-songs', 'r-and-b-digital-songs', 'r-and-b-streaming-songs', 
                          'hot-rap-songs', 'rap-airplay-songs','rap-digital-songs', 'rap-streaming-songs',
                          'rhythmic-songs', 'hot-latin-songs', 'latin-digital-songs', 'latin-streaming-songs', 
                          'latin-airplay-songs', 'latin-pop-airplay-songs', 'regional-mexican-airplay-songs', 
                          'hot-christian-adult-contemporary-songwriters','dance-electronic-songwriters',
                          'hot-rock-songwriters','hot-latin-songswriters','rap-songwriters','r-and-b-songwriters',
                          'hot-r-and-and-b-hip-hop-songwriters','hot-country-songwriters','hot-100-songwriters',
                          'candaian-hot-100-artists','kid-albums-artists','bluegrass-artists','folk-artists',
                          'reggae-albums-artists','blues-albums-artists','world-albums-artists',
                          'new-age-albums-artists', 'smooth-jazz-songs-artists','contemporary-jazz-artists',
                          'traditional-jazz-albums-artists', 'jazz-albums-artists',
                          'classical-crossover-albums-artists','traditional-classical-albums-artists',
                          'classical-albums-artists', 'gospel-streaming-songs-artists',
                          'gospel-digital-songs-artists','hot-gospel-songs-artists', 'gospel-albums-artists',
                          'top-gospel-artists-male','top-gospel-artists-female','top-gospel-artists',
                          'hot-christian-adult-contemporary-artists', 'christian-streaming-songs-artists',
                          'christian-digital-songs-artists','hot-christian-songs-artists',
                          'top-christian-artists-male','top-christian-artists-female', 'top-christian-artists',
                          'top-new-dance-eletronic-artists','dance-electronic-streaming-songs-artists',
                          'dance-electronic-streaming-songs-artists','dance-electronic-digital-songs-artists', 
                          'hot-dance-electronic-songs-artists', 'top-dance-electronic-new-artists',
                          'top-dance-electronic-artists','latin-rhythm-albums-artists',
                          'tropical-albums-artists'] 

Album_Charts_EndYear = ['top-billboard-200-albums', 'current-albums', 'top-country-albums', 'top-rock-albums', 
                        'top-alternative-albums', 'top-r-and-b-hip-hop-albums', 'r-and-b-albums', 
                        'rap-albums', 'top-latin-albums', 'latin-pop-albums', 'regional-mexican-albums',
                        'top-canadian-albums','top-soundtracks-albums','kid-albums','cast-albums',
                        'bluegrass-albums','folk-albums','reggae-albums','blues-albums','world-albums',
                        'new-age-albums','contemporary-jazz-albums','traditional-jazz-albums', 
                        'jazz-albums','classical-crossover-albums', 'traditional-classical-albums',
                        'classical-albums','gospel-albums','christian-albums','dance-electronic-albums',
                        'latin-rhythm-albums-','tropical-albums']  

Labels_Charts_EndYear = ['labels', 'hot-100-imprints', 'hot-100-labels', 'the-billboard-200-imprints', 
                         'the-billboard-200-labels', 'streaming-songs-labels', 'radio-songs-labels']

# %% [markdown]
# ### Collecting Current Chart Data

# %%
#ChartData(name, date=None, year=None, fetch=True, timeout=25)
def current_search(chart_name): 
    chart_results = billboard.ChartData(chart_name) 
    
    song_title = [] 
    song_artist = []  
    current_rank = [] 
    number_of_weeks_on_chart = [] 
    peak_position = [] 
    last_position = [] 
    song_image = []


    for song in chart_results: 
        song_title.append(song.title) 
        song_artist.append(song.artist) 
        current_rank.append(song.rank)
        number_of_weeks_on_chart.append(song.weeks)
        peak_position.append(song.peakPos) 
        last_position.append(song.lastPos) 
        song_image.append(song.image)
    
    
    
    chart = pd.DataFrame({'artist_name': song_artist,
                          'track_name': song_title, 
                          'rank': current_rank, 
                          'weeks_on_chart' : number_of_weeks_on_chart,
                          'peak_position' : peak_position,
                          'last_position' : last_position, 
                          'song_image': song_image})  
    
    return chart

# %% [markdown]
# ## Current Artist Charts

# %%
charts = {} 
artist_charts = ['artist-100','social-50', 'emerging-artists', 'next-big-sound-25', 'canada-emerging-artists']

for name in artist_charts:
    charts[name] = current_search(name)

# %%
charts['artist-100']
# Out:
#             artist_name track_name  rank  weeks_on_chart  peak_position  \
# 0                   BTS                1             218              1
# 1         Ariana Grande                2             305              1
# 2          Shawn Mendes                3             287              1
# 3            Pentatonix                4              73              1
# 4          Mariah Carey                5              51              5
# 5         Michael Buble                6              54              3
# 6            Luke Combs                7             197              1
# 7         Billie Eilish                8             120              1
# 8         Morgan Wallen                9              92              4
# 9             Bad Bunny               10             143              2
# 10          Bing Crosby               11              37              8
# 11     Carrie Underwood               12             224              1
# ...

# %% [markdown]
# ## Current Song Charts

# %%
charts = {} 
song_charts = ['hot-100', 'billboard-200','streaming-songs',
                    'digital-song-sales', 'billboard-global-200', 'billboard-global-excl-us',
                    'pop-songs','adult-contemporary', 'adult-pop-songs', 'country-songs', 
                    'country-streaming-songs', 'country-digital-song-sales', 'rock-songs', 
                    'rock-streaming-songs', 'rock-streaming-songs', 'rock-digital-song-sales', 
                    'hot-alternative-songs', 'alternative-streaming-songs', 'alternative-digital-song-sales',
                    'hot-hard-rock-songs', 'hard-rock-streaming-songs','hard-rock-digital-song-sales', 
                    'hot-mainstream-rock-tracks', 'r-b-hip-hop-songs', 'r-and-b-hip-hop-streaming-songs', 
                    'r-and-b-hip-hop-digital-song-sales', 'r-and-b-songs', 'r-and-b-streaming-songs',
                    'r-and-b-digital-song-sales', 'rap-song', 'rap-streaming-songs', 'hot-rap-tracks',
                    'rap-digital-song-sales', 'mainstream-r-and-b-hip-hop', 'rhythmic-40', 'latin-songs', 
                    'latin-streaming-songs', 'latin-digital-song-sales', 'dance-electronic-songs', 
                    'dance-electronic-streaming-songs', 'dance-electronic-digital-song-sales', 
                    'dance-club-play-songs', 'christian-songs', 'christian-streaming-songs', 
                    'christian-digital-song-sales', 'hot-christian-adult-contemporary',
                    'gospel-songs', 'gospel-digital-song-sales', 'contemporary-jazz', 'jazz-songs', 
                    'top-triller-global', 'top-triller-us', 'hot-holiday-songs', 'holiday-streaming-songs',
                    'holiday-songs', 'holiday-season-digital-song-sales', 'summer-songs', 'canadian-hot-100', 
                    'hot-canada-digital-song-sales', 'canada-ac', 'canada-chr-top-40', 'canada-country',
                    'canada-hot-ac', 'canada-rock', 'mexico', 'mexico-ingles', 'mexico-popular', 
                    'mexico-espanol', 'japan-hot-100', 'billboard-korea-100', 'billboard-argentina-hot-100',
                    'official-uk-songs', 'uk-digital-song-sales', 'euro-digital-song-sales', 
                    'france-digital-song-sales', 'germany-songs', 'italy-digital-song-sales',
                    'spain-digital-song-sales', 'switzerland-digital-song-sales', 
                    'australia-digital-song-sales', 'bubbling-under-hot-100-singles', 'world-digital-song-sales']

for name in song_charts:
    charts[name] = current_search(name)

# %%
charts['hot-100']
# Out:
#                                           artist_name  \
# 0                                        Mariah Carey
# 1                        24kGoldn Featuring iann dior
# 2                                          Brenda Lee
# 3                                       Ariana Grande
# 4                                         Bobby Helms
# 5                                       Andy Williams
# 6                                          The Weeknd
# 7                            Drake Featuring Lil Durk
# 8           Justin Bieber Featuring Chance The Rapper
# 9                                      Jose Feliciano
# 10                                              Wham!
# 11               Gabby Barrett Featuring Charlie Puth
# 12                           Chris Brown & Young Thug
# 13                                          Burl Ives
# 14                                        Dean Martin
# 15                                      Nat King Cole
# ...

# %% [markdown]
# ## Current Album Charts

# %%
charts = {} 
album_charts = ['top-album-sales','current-albums', 'catalog-albums', 'independent-albums',
                'soundtracks', 'vinyl-albums','country-albums', 'bluegrass-albums', 
                'americana-folk-albums', 'rock-albums','alternative-albums', 'hard-rock-albums', 
                'r-b-hip-hop-albums', 'r-and-b-albums', 'latin-albums', 'regional-mexican-albums', 
                'latin-pop-albums', 'tropical-albums', 'latin-rhythm-albums', 
                'dance-electronic-albums', 'christian-albums', 'classical-albums', 
                'classical-crossover-albums', 'traditional-classic-albums', 'jazz-albums', 
                'traditional-jazz-albums', 'heatseekers-albums', 'holiday-albums', 
                'canadian-albums', 'official-uk-albums', 'german-albums', 'greece-albums',
                'italy-albums', 'australian-albums', 'blues-albums', 'cast-albums',
                'comedy-albums', 'compilation-albums', 'kids-albums', 'new-age-albums',
                'reggae-albums', 'tastemaker-albums', 'world-albums'] 

for name in album_charts: 
    charts[name] = current_search(name)

# %%
charts['top-album-sales']
# Out:
#                         artist_name  \
# 0                      Shawn Mendes
# 1                  Carrie Underwood
# 2                      Dolly Parton
# 3                 The White Stripes
# 4                             AC/DC
# 5                        Pentatonix
# 6                               BTS
# 7                   Chris Stapleton
# 8                      Harry Styles
# 9               Vince Guaraldi Trio
# 10                     Taylor Swift
# 11                            TWICE
# 12                       Pentatonix
# 13                    Ariana Grande
# 14                            Queen
# 15                    Billie Eilish
# 16                      The Beatles
# 17                      Josh Groban
# 18              Death Cab For Cutie
# 19                    Michael Buble
# 20                   Andrea Bocelli
# 21                Bruce Springsteen
# 22                       Soundtrack
# 23                         YUNGBLUD
# 24       Bob Marley And The Wailers
# ...

# %%
charts.keys()
# Out:
# dict_keys(['hot-100', 'billboard-200', 'artist-100', 'social-50', 'streaming-songs', 'radio-songs', 'digital-song-sales', 'top-album-sales', 'current-albums', 'independent-albums', 'billboard-global-200', 'greatest-billboard-200-albums', 'greatest-billboard-200-artists', 'greatest-hot-100-singles', 'greatest-hot-100-artists', 'greatest-of-all-time-pop-songs', 'greatest-of-all-time-pop-songs-artists', 'pop-songs', 'country-songs', 'country-albums', 'country-streaming-songs', 'country-digital-song-sales', 'rock-songs', 'rock-albums', 'rock-streaming-songs', 'rock-digital-song-sales', 'hot-alternative-songs', 'alternative-albums', 'alternative-streaming-songs', 'alternative-digital-song-sales', 'r-b-hip-hop-songs', 'r-b-hip-hop-albums', 'r-and-b-hip-hop-streaming-songs', 'hot-r-and-b-hip-hop-airplay', 'r-and-b-hip-hop-digital-song-sales', 'rap-song', 'rap-albums', 'rap-streaming-songs', 'rap-digital-song-sales', 'latin-songs', 'latin-albums', 'latin-streaming-songs', 'latin-digital-song
# ...

# %%
for key in charts.keys(): 
    print(charts[key])

# %% [markdown]
# ### Collecting Year-End Chart Data

# %%
#ChartData(name, date=None, year=None, fetch=True, timeout=25)
def year_search(chart_name, years): 
    song_title = [] 
    song_artist = []  
    current_rank = [] 
    song_image = []
    year_list = []
    
    for set_year in years: 
        chart_results = billboard.ChartData(chart_name, year=set_year) 
    
        for song in chart_results: 
            song_title.append(song.title) 
            song_artist.append(song.artist) 
            current_rank.append(song.rank) 
            song_image.append(song.image)
            year_list.append(set_year)
    
    
    chart = pd.DataFrame({'artist_name': song_artist,
                          'track_name': song_title, 
                          'rank': current_rank, 
                          'song_image' : song_image,
                          'year' : year_list}) 
    
    chart.groupby('year')
    
    return chart

# %%
years = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

charts_yearend = {}

for name in end_of_year_charts:
    charts_yearend[name] = year_search(name, years)

# %%
charts_yearend.keys()
# Out:
# dict_keys(['top-artists', 'top-artists-female', 'top-artists-male', 'top-new-artists', 'hot-100-artists', 'hot-100-songs'])

# %%
charts_yearend['top-artists']
# Out:
#        artist_name track_name  rank  \
# 0            Adele                1
# 1          Rihanna                2
# 2       Katy Perry                3
# 3        Lady Gaga                4
# 4        Lil Wayne                5
# ..             ...        ...   ...
# 895  Fleetwood Mac               96
# 896     The Weeknd               97
# 897    Eric Church               98
# 898   benny blanco               99
# 899     Luke Bryan              100
#
#                                             song_image  year
# 0    https://charts-static.billboard.com/img/2009/1...  2011
# 1    https://charts-static.billboard.com/img/2006/1...  2011
# 2    https://charts-static.billboard.com/img/2008/1...  2011
# 3    https://charts-static.billboard.com/img/2017/0...  2011
# 4    https://charts-static.billboard.com/img/2017/0...  2011
# ..                                                 ...   ...
# 895  https://charts-static.billboard.com/img/2017/0...  2019
# ...
