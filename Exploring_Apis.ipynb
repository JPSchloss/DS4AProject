# %% [markdown]
# # Tik Tok API Exploration

# %%
import pandas as pd
import numpy as np
import json
import random

# %% [markdown]
# ### Installing the API

# %%
pip install TikTokApi

pip install pyppeteer

# %%
pip install TikTokApi
python -m playwright install

# %% [markdown]
# #### Notes:
# May need to update chromedriver... kinda complicated. This article helped...
# https://www.kenst.com/2015/03/including-the-chromedriver-location-in-macos-system-path/
#
# Simpler Alternative:
#
# brew cask install chromedriver
#
# brew reinstall chromedriver
#
# chromedriver --version
#
# URL for Package: https://github.com/davidteather/TikTok-Api#the-gettiktokbyurl-method
#
# Examples of the Package Being Used:
#     https://towardsdatascience.com/how-to-collect-data-from-tiktok-tutorial-ab848b40d191

# %% [markdown]
# ### Running the API

# %%
from TikTokApi import TikTokApi
#from TikTokApi.browser import get_params
#get_params()
api = TikTokApi.get_instance()

# %% [markdown]
# ### Trending Videos on Tik Tok

# %%
results = 30

trending = api.trending(count=results)

#trending_df = pd.DataFrame(trending)

#trending_df

#for tiktok in trending:
# Prints the text of the tiktok
    #print(tiktok['desc'])
    
trending[1]

#Videos worked here homeskillzit

# %% [markdown]
# ### Trending Music

# %%
trendingMusic = api.discoverMusic()

print(trendingMusic)

for tiktok in trendingMusic:
    print(tiktok['cardItem']['title'], tiktok['cardItem']['description'],
         tiktok['cardItem']['subTitle'], tiktok['cardItem']['extraInfo']['posts'])

# %%
trendingMusic[0]

# %% [markdown]
# ### Trending Challenges

# %%
trendingChallenges = api.discoverHashtags()

for tiktok in trendingChallenges:
    print(tiktok['cardItem']['title'], tiktok['cardItem']['description'],
         tiktok['cardItem']['subTitle'])
    
trendingChallenges[0]

# %% [markdown]
# ### Get Videos By Username

# %%
n_videos = 10
username = 'washingtonpost'
user_videos = api.byUsername(username, count=n_videos)
user_videos
#for tiktok in user_videos:
    #print(tiktok['desc'])

# %% [markdown]
# ### Get Videos By Sound ID

# %%
count = 10

# You can find this from a tiktok getting method in another way or find songs from the discoverMusic method.
soundId = "6601861313180207878"

tiktoks = api.bySound(soundId, count=count)

for tiktok in tiktoks:
    print(tiktok['itemInfos']['text'])
    
#Different data sturucture reutrned here... need to be aware of that when diving deeper.

# %%
tiktoks[1]

# %% [markdown]
# ### TikToks By Hashtag

# %%
count = 10

tiktoks = api.byHashtag("funny", count=count)

for tiktok in tiktoks:
    print(tiktok)

# %% [markdown]
# ### Tik Toks By A Set Value

# %%
# By ID - this code is flawed at moment... dont use... mwhahahahaha
count = 10

tiktoks = api.getTikTokById(id="XXXXXXXXXXXX", count=count)

for tiktok in tiktoks:
    print(tiktok)

    
# By URL

tiktoks = api.getTikTokByUrl(id="XXXXXXXXXXXX", count=count)

for tiktok in tiktoks:
    print(tiktok)

# %% [markdown]
# ### Getting User Information

# %%
count = 10
username = 'washingtonpost'

tiktoks = api.getUser(username, count=count)

print(' Unique ID:\t', tiktoks['user']['uniqueId'], '\n', 'NickName:\t', tiktoks['user']['nickname'], '\n', 
      'Verified:\t', tiktoks['user']['verified'], '\n', 'Following:\t', tiktoks['stats']['followingCount'], '\n', 
      'Followers:\t', tiktoks['stats']['followerCount'], '\n', 'Heart Count:\t', tiktoks['stats']['heartCount'],
      '\n', 'Video Count:\t', tiktoks['stats']['videoCount'])

# %% [markdown]
# ### Tik Toks by Sound ID

# %%
soundId = "6601861313180207878"

tiktoks = api.bySound(soundId, count=5)

for tiktok in tiktoks:
    print(tiktok['itemInfos']['video']['urls'])
    print(tiktok['musicInfos']['playUrl'][0]) #This gives the actual track as a clickable link

# %%
tiktoks[1]

# %% [markdown]
# ### Can Automatically Play It With...

# %%
play_url = tiktok['musicInfos']['playUrl'][0] #Can modify this to actualy play the tiktoks videos

from IPython.display import IFrame
IFrame(play_url, width=300, height=30)

# %% [markdown]
# ### Can Also Get Song Album Cover

# %%
# These are different links found in the API JSON
thumb_url = 'https://p16-sg.tiktokcdn.com/aweme/100x100/tos-alisg-i-0000/cdc013e009284516a18e4d79df85e96e.jpeg'
medium_url = 'https://p16-sg.tiktokcdn.com/aweme/200x200/tos-alisg-i-0000/cdc013e009284516a18e4d79df85e96e.jpeg'

from IPython.display import IFrame
IFrame(medium_url, width=300, height=300)

# %% [markdown]
# ## Fooling Around Things ... Not Yet Finished

# %%
video_url = trending[0]['video']['playAddr']

from IPython.display import IFrame
IFrame(video_url, width=700, height=500)

# %%
tiktoks = api.getTikTokByUrl('https://www.tiktok.com/@charlidamelio/video/6861737179530480901')

print(tiktoks)

tiktoks['itemInfo']['itemStruct']['video']['downloadAddr']

#test = api.get_Video_By_DownloadURL(tiktoks['itemInfo']['itemStruct']['video']['downloadAddr'])

test = api.get_Video_By_Url('https://www.tiktok.com/@charlidamelio/video/6861737179530480901')

test

# %% [markdown]
# # Spotify API Exploration

# %% [markdown]
# Resource:
#
#     https://medium.com/@maxtingle/getting-started-with-spotifys-api-spotipy-197c3dc6353b
#
#     https://developer.spotify.com/documentation/web-api/reference-beta/
#
#     https://spotipy.readthedocs.io/en/latest/#
#
#     https://developer.spotify.com/documentation/web-api/reference-beta/

# %% [markdown]
# Notes:
# - May need to seek approval for using this data source in a commercial setting.

# %% [markdown]
# ### Installing the Spotipy Package

# %%
# This may need to be run in the terminal. Will need to clean this up when on AWS. 
pip install spotipy

# %% [markdown]
# ### Setting Up the API
#
# This employs a config document to keep the id and api a secret. This will need to be more secure in the future. There is a fairly easy way to set it up in AWS. Resource: http://veekaybee.github.io/2020/02/25/secrets/

# %% [markdown]
# Spotify API has a maximum search of 10,000
#
# sp.search has a 50 results max... maybe

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import config as config

cid = config.spotify_api['id']
secret = config.spotify_api['secret']

client_credentials_manager = SpotifyClientCredentials(client_id = cid, client_secret = secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# #### Getting Tracks Based on Year

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,100,50):
    track_results = sp.search(q='year:2019', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2019&type=track&offset=50&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
# ...

# %%
import pandas as pd
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe.shape)
track_dataframe.head(30)
# Out:
# (100, 4)
#         artist_name                                      track_name  \
# 0            Clairo                                           Sofia
# 1      Harry Styles                                Watermelon Sugar
# 2        Juice WRLD                                         Robbery
# 3       Post Malone                                         Circles
# 4       Roddy Ricch                                         The Box
# 5           Wallows               Are You Bored Yet? (feat. Clairo)
# 6     Lewis Capaldi                               Someone You Loved
# 7      Travis Scott                             HIGHEST IN THE ROOM
# 8           JP Saxe  If the World Was Ending - feat. Julia Michaels
# 9        Juice WRLD        Bandit (with YoungBoy Never Broke Again)
# 10     Harry Styles                                          Golden
# 11         Lil Peep                                   Star Shopping
# 12        SAINt JHN                           Roses - Imanbek Remix
# ...

# %% [markdown]
# ### Getting the Featured Playlists
# This will probably need to be edited and played with.
#
# Source: https://github.com/plamere/spotipy/blob/master/examples/show_featured_playlists.py

# %%
response = sp.featured_playlists()
print(response['message'])

while response:
    playlists = response['playlists']
    for i, item in enumerate(playlists['items']):
        print(playlists['offset'] + i, item['name'])

    if playlists['next']:
        response = sp.next(playlists)
    else:
        response = None
# Out:
# Selección del editor
# 0 '90s Baby Makers
# 1 Deep Sleep
# 2 Late Night Vibes
# 3 Dark & Stormy
# 4 White Noise
# 5 Soft Rock
# 6 Calm Down
# 7 Sleep
# 8 Peaceful Piano
# 9 Night Rain
# 10 Chill Hits
# 11 Peaceful Meditation

# %%
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/browse/featured-playlists?timestamp=2020-12-02T02%3A33%3A05&offset=0&limit=20',
#  'items': [{'collaborative': False,
#    'description': "What we're gonna do right now is go back—back in time. Here are all your favorite '90s R&B slow jams!",
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVEvzGeX3eRs'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVEvzGeX3eRs',
#    'id': '37i9dQZF1DWVEvzGeX3eRs',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000039d574d6f27a73e668fee93ef',
#      'width': None}],
#    'name': "'90s Baby Makers",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': None,
# ...

# %% [markdown]
# ### Top Songs For An Artist

# %%
urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'

response = sp.artist_top_tracks(urn)

for track in response['tracks']:
    print(track['artists'][0]['name'], '\t', track['name'])

# %%
response

# %% [markdown]
# ### Top New Releases

# %%
response = sp.new_releases()

while response:
    albums = response['albums']
    for i, item in enumerate(albums['items']):
        print(albums['offset'] + i, item['artists'][0]['name'], '\t - \t', item['name'])

    if albums['next']:
        response = sp.next(albums)
    else:
        response = None
# Out:
# 0 Bad Bunny 	 - 	 EL ÚLTIMO TOUR DEL MUNDO
# 1 Miley Cyrus 	 - 	 Plastic Hearts
# 2 NCT 	 - 	 NCT RESONANCE Pt. 2 - The 2nd Album
# 3 Sabrina Claudio 	 - 	 Christmas Blues (with The Weeknd)
# 4 SAINt JHN 	 - 	 Smack DVD (feat. Kanye West)
# 5 Lil Yachty 	 - 	 Lil Boat 3.5
# 6 Jennifer Lopez 	 - 	 In The Morning
# 7 Nathan Dawe 	 - 	 No Time For Tears
# 8 Cordae 	 - 	 The Parables
# 9 Phoebe Bridgers 	 - 	 If We Make It Through December
# 10 YUNGBLUD 	 - 	 mars
# 11 Q 	 - 	 Alone
# 12 Juicy J 	 - 	 THE HUSTLE CONTINUES
# 13 Silver Sphere 	 - 	 football game
# 14 Duncan Laurence 	 - 	 Arcade (feat. FLETCHER)
# 15 Purple Disco Machine 	 - 	 Exotica
# 16 Camilo 	 - 	 BEBÉ
# 17 Sam Fischer 	 - 	 For Now
# 18 Fivio Foreign 	 - 	 Trust
# 19 Granger Smith 	 - 	 Country Things, Vol. 2
# 20 Arlo Parks 	 - 	 Caroline
# 21 Ovy On The Drums 	 - 	 Miedito o Qué? (feat. KAROL G)
# 22 Saba 	 - 	 So and So / Areyoudown? Pt. 2
# 23 The Smashing Pumpkins 	 - 	 CYR
# ...

# %%
response = sp.new_releases()
response
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
# ...

# %% [markdown]
# ### Identifying Related Artists

# %%
artist_name = 'weezer'

result = sp.search(q='artist:' + artist_name, type='artist')

name = result['artists']['items'][0]['name']
uri = result['artists']['items'][0]['uri']
print(uri)
related = sp.artist_related_artists(uri)
print('Related artists for', name)
for artist in related['artists']:
    print('  ', artist['name'])
# Out:
# spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# Related artists for Weezer
#    The Presidents Of The United States Of America
#    Cake
#    Everclear
#    Third Eye Blind
#    Jimmy Eat World
#    Sugar Ray
#    The Smashing Pumpkins
#    OK Go
#    311
#    Modest Mouse
#    Bush
#    Barenaked Ladies
#    Silversun Pickups
#    Violent Femmes
#    Reel Big Fish
#    Goldfinger
#    Jane's Addiction
#    Bowling For Soup
#    Beck
#    New Found Glory

# %%
related

# %% [markdown]
# ### Getting Info For One Track

# %%
urn = 'spotify:track:0Svkvt5I79wficMFgaqEQJ'

track = sp.track(urn)

track
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#     'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#     'id': '3jOstUTkEu2JkjvRdBA5Gu',
#     'name': 'Weezer',
#     'type': 'artist',
#     'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/04xe676vyiTeYNXw15o9jT'},
#   'href': 'https://api.spotify.com/v1/albums/04xe676vyiTeYNXw15o9jT',
#   'id': '04xe676vyiTeYNXw15o9jT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273baee44673c99e67745a9b8d0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02baee44673c99e67745a9b8d0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851baee44673c99e67745a9b8d0',
#     'width': 64}],
#   'name': 'Pinkerton',
# ...

# %% [markdown]
# ### Getting Info For One Album

# %%
uri = 'spotify:album:04xe676vyiTeYNXw15o9jT'

album = sp.album(uri)

album
#Shows info for every track in the album... really detailed.
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'},
#    'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu',
#    'id': '3jOstUTkEu2JkjvRdBA5Gu',
#    'name': 'Weezer',
#    'type': 'artist',
#    'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}],
#  'available_markets': [],
#  'copyrights': [{'text': '© 1996 Geffen Records Inc.', 'type': 'C'},
#   {'text': '℗ 1996 UMG Recordings, Inc.', 'type': 'P'}],
#  'external_ids': {'upc': '00720642500729'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/04xe676vyiTeYNXw15o9jT'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/04xe676vyiTeYNXw15o9jT',
#  'id': '04xe676vyiTeYNXw15o9jT',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273baee44673c99e67745a9b8d0',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02baee44673c99e67745a9b8d0',
# ...

# %% [markdown]
# ### Getting Artists Albums

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP/albums?offset=0&limit=20&include_groups=album',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2WX2uTcsvV5OnS0inACecP'},
#      'href': 'https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP',
#      'id': '2WX2uTcsvV5OnS0inACecP',
#      'name': 'Birdy',
#      'type': 'artist',
#      'uri': 'spotify:artist:2WX2uTcsvV5OnS0inACecP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
# ...

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

results = sp.artist_albums(birdy_uri, album_type='album')

albums = results['items']

while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print((album['name']))
# Out:
# Beautiful Lies
# Beautiful Lies
# Beautiful Lies (Deluxe)
# Beautiful Lies (Deluxe)
# Fire Within
# Fire Within
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy
# Birdy
# Birdy
# Birdy
# Birdy (Deluxe Version)

# %% [markdown]
# ### Getting Tracks For An Artist

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Radiohead&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#        'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#        'id': '4Z8W4fKeB5YxbusRsdQVPb',
#        'name': 'Radiohead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6400dnyeDyD2mIFHfkwHXN'},
#      'href': 'https://api.spotify.com/v1/albums/6400dnyeDyD2mIFHfkwHXN',
#      'id': '6400dnyeDyD2mIFHfkwHXN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732f85b65d3ac4d3d7f806ca11',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022f85b65d3ac4d3d7f806ca11',
# ...

# %%
artist_name = 'Radiohead'

results = sp.search(q=artist_name, limit=50)

print(artist_name)
for i, t in enumerate(results['tracks']['items']):
    print(' ', i+1, t['name'])
# Out:
# Radiohead
#   1 Creep
#   2 Karma Police
#   3 High And Dry
#   4 No Surprises
#   5 Exit Music (For a Film)
#   6 Treefingers
#   7 Weird Fishes/ Arpeggi
#   8 Fake Plastic Trees
#   9 Nude
#   10 Paranoid Android
#   11 House Of Cards
#   12 Everything In Its Right Place
#   13 Jigsaw Falling Into Place
#   14 All I Need
#   15 How To Disappear Completely
#   16 15 Step
#   17 Reckoner
#   18 Bodysnatchers
#   19 Idioteque
#   20 Let Down
#   21 Subterranean Homesick Alien
#   22 The National Anthem
#   23 Pyramid Song
#   24 Daydreaming
#   25 Just
#   26 True Love Waits
#   27 High and Dry
#   28 Street Spirit (Fade Out)
#   29 Fake Plastic Trees
#   30 Present Tense
#   31 Just
#   32 Black Star
#   33 Talk Show Host
#   34 The Bends
#   35 Street Spirit (Fade Out)
#   36 My Iron Lung
#   37 Planet Telex
#   38 (Nice Dream)
#   39 Weird Fishes/ Arpeggi
#   40 Bullet Proof ... I Wish I Was
#   41 2 + 2 = 5
#   42 Bones
#   43 Paranoid Android
#   44 Motion Picture Soundtrack
# ...

# %% [markdown]
# ### Getting Artist Images

# %%
from IPython.display import IFrame
name = 'Radiohead'

results = sp.search(q='artist:' + name, type='artist')
items = results['artists']['items']
if len(items) > 0:
    artist = items[0]
    print(artist['name'], artist['images'][1]['url'])

IFrame(artist['images'][1]['url'], width=500, height=500) #Need to change cause it is too big right now.
# Out:
# Radiohead https://i.scdn.co/image/563754af10b3d9f9f62a3458e699f58c4a02870f
#         <iframe
#             width="500"
#             height="500"
#             src="https://i.scdn.co/image/563754af10b3d9f9f62a3458e699f58c4a02870f"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Featured Playlists

# %%
playlists = sp.featured_playlists()

playlists['message']
playlists
# Need to play with this to clena it up.

# %% [markdown]
# ### Search Markets

# %%
markets = sp.search_markets(q='wap', markets=['US'])

markets
#Works but needs optimization... probably only selecting markets of interest.
# Out:
# /Users/jonathanschlosser/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py:566: UserWarning: Searching multiple markets is an experimental feature. Please be aware that this method's inputs and outputs can change in the future.
#   UserWarning,
# /Users/jonathanschlosser/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py:576: UserWarning: Searching multiple markets is poorly performing.
#   UserWarning,
# {'US': {'tracks': {'href': 'https://api.spotify.com/v1/search?query=wap&type=track&market=US&offset=0&limit=10',
#    'items': [{'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4kYSro6naA4h99UJvo89HB'},
#         'href': 'https://api.spotify.com/v1/artists/4kYSro6naA4h99UJvo89HB',
#         'id': '4kYSro6naA4h99UJvo89HB',
#         'name': 'Cardi B',
#         'type': 'artist',
#         'uri': 'spotify:artist:4kYSro6naA4h99UJvo89HB'},
# ...

# %% [markdown]
# ### Public Playlists For A User

# %%
user = 'spotify'

playlists = sp.user_playlists(user)

while playlists:
    for i, playlist in enumerate(playlists['items']):
        print(
            "%4d %s %s" %
            (i +
             1 +
             playlists['offset'],
             playlist['uri'],
             playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None

# %% [markdown]
# ### Audio Analysis of A Track

# %%
urn = 'spotify:track:0Svkvt5I79wficMFgaqEQJ'

track = sp.audio_analysis(urn)

track

# %% [markdown]
# ### Audio Features Of A Track

# %%
urn = 'spotify:track:0Svkvt5I79wficMFgaqEQJ'

track = sp.audio_features(urn)

track
# Out:
# [{'danceability': 0.478,
#   'energy': 0.708,
#   'key': 1,
#   'loudness': -5.021,
#   'mode': 1,
#   'speechiness': 0.0623,
#   'acousticness': 0.0556,
#   'instrumentalness': 0,
#   'liveness': 0.0958,
#   'valence': 0.656,
#   'tempo': 148.051,
#   'type': 'audio_features',
#   'id': '0Svkvt5I79wficMFgaqEQJ',
#   'uri': 'spotify:track:0Svkvt5I79wficMFgaqEQJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Svkvt5I79wficMFgaqEQJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Svkvt5I79wficMFgaqEQJ',
#   'duration_ms': 243531,
#   'time_signature': 4}]

# %% [markdown]
# ### Playable Previews

# %%
url = 'https://p.scdn.co/mp3-preview/37700576f58eb93f8e2f4469eafe7725635f9867?cid=a9915d84a306475b862d512c14ba62a6'
# Need to use the Preview URL (preview_url)

IFrame(url, width=300, height=50)

# %% [markdown]
# # Youtube API

# %% [markdown]
# Resource:
#     https://towardsdatascience.com/tutorial-using-youtubes-annoying-data-api-in-python-part-1-9618beb0e7ea

# %%
# May Need to be run in the terminal
pip install --upgrade google-api-python-client

# %% [markdown]
# # Tidal - Maybe?

# %% [markdown]
# # Apple Music API Exploration

# %% [markdown]
# Cost to enroll in the developer program in order to get the keys and whatnot... $99 per year...
#
# Resource:
#     https://apple-music-python.readthedocs.io/en/latest/

# %%
# Run in Terminal
pip install apple-music-python

# %% [markdown]
# # Instagram API

# %% [markdown]
# **Not Really The Best - Limited Info Accessible**
#
# Resources:
#
# https://developers.facebook.com/docs/instagram-basic-display-api/guides/getting-profiles-and-media
#
# https://andrewly.medium.com/an-easy-guide-to-use-instagrams-new-api-in-2020-cd353b35c749
#
# https://developers.facebook.com/docs/instagram-basic-display-api/reference/media#fields
#
# https://medium.com/@evanturibe/getting-started-with-instagram-api-in-20-minutes-or-less-672d6211de

# %% [markdown]
# # Billboard
#
# **Billboard has an API**
# https://github.com/guoguo12/billboard-charts
# https://rapidapi.com/LDVIN/api/billboard-api

# %%
# Run in Terminal
pip install billboard.py

# %%
import billboard

# By Day!!!!

Hot100 = billboard.ChartData('hot-100')

Hot100[0:100]
# Out:
# [billboard.ChartEntry(title='Life Goes On', artist='BTS'),
#  billboard.ChartEntry(title='Mood', artist='24kGoldn Featuring iann dior'),
#  billboard.ChartEntry(title='Dynamite', artist='BTS'),
#  billboard.ChartEntry(title='Positions', artist='Ariana Grande'),
#  billboard.ChartEntry(title='I Hope', artist='Gabby Barrett Featuring Charlie Puth'),
#  billboard.ChartEntry(title='Holy', artist='Justin Bieber Featuring Chance The Rapper'),
#  billboard.ChartEntry(title='Laugh Now Cry Later', artist='Drake Featuring Lil Durk'),
#  billboard.ChartEntry(title='Monster', artist='Shawn Mendes & Justin Bieber'),
#  billboard.ChartEntry(title='Blinding Lights', artist='The Weeknd'),
#  billboard.ChartEntry(title='Lemonade', artist='Internet Money & Gunna Featuring Don Toliver & NAV'),
#  billboard.ChartEntry(title='Therefore I Am', artist='Billie Eilish'),
#  billboard.ChartEntry(title='Body', artist='Megan Thee Stallion'),
#  billboard.ChartEntry(title='Blue & Grey', artist='BTS'),
# ...

# %%
song = Hot100[0]
print(song)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-9b8d84792021> in <module>
#       1 song = Hot100[0]
# ----> 2 print(song[0])
#
# TypeError: 'ChartEntry' object is not subscriptable

# %%
charts = ['hot-100', 'billboard-200']

# %%
Song_Title = []
Song_Artist = []



for song in Hot100:
    Song_Title.append(song.title)
    Song_Artist.append(song.artist)
    

Hot_100_Billboard = pd.DataFrame({'artist_name': Song_Artist, 
                                'track_name': Song_Title})

Hot_100_Billboard.head()
# Out:
#                             artist_name    track_name
# 0                                   BTS  Life Goes On
# 1          24kGoldn Featuring iann dior          Mood
# 2                                   BTS      Dynamite
# 3                         Ariana Grande     Positions
# 4  Gabby Barrett Featuring Charlie Puth        I Hope

# %%
song = Hot100[0]  # Get no. 1 song on chart

print('Song Title:', song.title)

print('Song Artist:', song.artist)

print('Current Rank:', song.rank)

print('Number of Weeks on Chart:', song.weeks)

print('Peak Position:', song.peakPos)

print('Last Position:', song.lastPos)

print(song.image)

# %%
billboard.charts()

#'hot-100', 'billboard-200', 'artist-100', 'social-50', 'streaming-songs', 'digital-song-sales', 'top-album-sales',
# Also a lot of different country-specific charts
# Out:
# ['hot-100',
#  'billboard-200',
#  'artist-100',
#  'social-50',
#  'streaming-songs',
#  'radio-songs',
#  'digital-song-sales',
#  'top-album-sales',
#  'current-albums',
#  'catalog-albums',
#  'independent-albums',
#  'soundtracks',
#  'vinyl-albums',
#  'billboard-global-200',
#  'billboard-global-excl-us',
#  'greatest-billboard-200-albums',
#  'greatest-billboard-200-artists',
#  'greatest-hot-100-singles',
#  'greatest-hot-100-artists',
#  'greatest-hot-100-songs-by-women',
#  'greatest-hot-100-women-artists',
#  'greatest-billboard-200-albums-by-women',
#  'greatest-billboard-200-women-artists',
#  'greatest-billboards-top-songs-80s',
#  'greatest-billboards-top-songs-90s',
#  'greatest-of-all-time-pop-songs',
#  'greatest-of-all-time-pop-songs-artists',
#  'greatest-adult-pop-songs',
#  'greatest-adult-pop-artists',
#  'greatest-country-songs',
#  'greatest-country-albums',
#  'greatest-country-artists',
#  'greatest-of-all-time-latin-artists',
# ...

# %%
# End of year charts... differ from the live chart
billboard.charts(year_end=True)

# %%
#ChartData(name, date=None, year=None, fetch=True, timeout=25)

Top100_2019 = billboard.ChartData('digital-songs', year=2019)

print(Top100_2019)

# %% [markdown]
# ### Other Resources
#
#  - https://towardsdatascience.com/real-time-twitter-sentiment-analysis-for-brand-improvement-and-topic-tracking-chapter-2-3-1caf05346721
#  - https://stackoverflow.com/questions/36074380/bokeh-area-plot-with-negative-values
