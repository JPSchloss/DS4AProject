# %% [markdown]
# # Spotify Script

# %%
import pandas as pd
import json
from IPython.display import IFrame

# %% [markdown]
# ### Setting Up The API

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import config as config

cid = config.spotify_api['id']
secret = config.spotify_api['secret']

client_credentials_manager = SpotifyClientCredentials(client_id = cid, client_secret = secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ### Top New Releases - Done

# %%
# Notes:
#   Genres not available in the returned info here. 
#   This returns new album releases... not tracks. 
#   No track, popularity, or 'explicit' information and no preview url. 

def top_new_releases():
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    release_date = []
    available_markets = []
    image_url = []

    response = sp.new_releases()

    while response:
        albums = response['albums']
        
        for i, item in enumerate(albums['items']):
            artist_name.append(item['artists'][0]['name'])
            artist_id.append(item['artists'][0]['id'])
            artist_uri.append(item['artists'][0]['uri'])
            album_name.append(item['name'])
            album_id.append(item['id'])
            album_uri.append(item['uri'])
            release_date.append(item['release_date'])
            available_markets.append(item['available_markets'])
            image_url.append(item['images'][2]['url'])
            
        if albums['next']:
            response = sp.next(albums)
        else:
            response = None
        
    new_releases_dataframe = pd.DataFrame({'artist_name' : artist_name,
                                'artist_id' : artist_id,
                                'artist_uri' : artist_uri,
                                'album_name' : album_name,
                                'album_id' : album_id,
                                'album_uri' : album_uri,
                                'release_date' : release_date,
                                'available_markets' : available_markets,
                                'image_url' : image_url})
    
    return new_releases_dataframe

# %%
new_releases = top_new_releases()

# %%
new_releases
# Out:
#         artist_name               artist_id  \
# 0          24kGoldn  6fWVd57NKTalqvmjRd2t8Z
# 1      Shawn Mendes  7n2wHs1TKAczGzO7Dd2rGr
# 2          Lil Baby  5f7VJjfbwm532GiveGC0ZK
# 3        Juice WRLD  4MCBfE4596Uoi2O4DtmEMz
# 4              TINI  7vXDAI8JwjW531ouMGbfcp
# ..              ...                     ...
# 94      salem ilese  3QJUFtGBGL05vo0kCJZsmT
# 95        Bleachers  2eam0iDomRHGBypaDQLwWI
# 96        Meek Mill  20sxb77xiYeusSH8cVdatc
# 97  Phoebe Bridgers  1r1uxoy19fzMxunt3ONAkG
# 98      girl in red  3uwAm6vQy7kWPS2bciKWx9
#
#                                artist_uri  \
# 0   spotify:artist:6fWVd57NKTalqvmjRd2t8Z
# 1   spotify:artist:7n2wHs1TKAczGzO7Dd2rGr
# 2   spotify:artist:5f7VJjfbwm532GiveGC0ZK
# 3   spotify:artist:4MCBfE4596Uoi2O4DtmEMz
# 4   spotify:artist:7vXDAI8JwjW531ouMGbfcp
# ..                                    ...
# 94  spotify:artist:3QJUFtGBGL05vo0kCJZsmT
# 95  spotify:artist:2eam0iDomRHGBypaDQLwWI
# 96  spotify:artist:20sxb77xiYeusSH8cVdatc
# 97  spotify:artist:1r1uxoy19fzMxunt3ONAkG
# 98  spotify:artist:3uwAm6vQy7kWPS2bciKWx9
#
#                              album_name                album_id  \
# 0                   Coco (feat. DaBaby)  2wIHInPRTBuGELQ3tdB3pc
# 1                                Wonder  3Lp4JKk2ZgNkybMRS3eZR5
# 2                               Errbody  6kQlFDnDGI6CnLOhhpvBhd
# 3         Real Shit (with benny blanco)  0GMu98ZhwAoTqk1hzEMicE
# 4                        TINI TINI TINI  16TT0OKoyEgD22nj70WUEi
# ..                                  ...                     ...
# 94                        Coke & Mentos  0uSrWUaD2vkXZhzpXKOfaS
# 95  chinatown (feat. Bruce Springsteen)  10fSu9RLAJlasIup4ylHPM
# 96                      QUARANTINE PACK  5VOW9zYV8KoErvgrLYqKR2
# 97                       Copycat Killer  4OC1SbVjw7X1L0l2OrpPPg
# 98       two queens in a king sized bed  38v3Ga4U869AXC0BKIzuXG
#
#                                album_uri release_date  \
# 0   spotify:album:2wIHInPRTBuGELQ3tdB3pc   2020-12-04
# 1   spotify:album:3Lp4JKk2ZgNkybMRS3eZR5   2020-12-04
# 2   spotify:album:6kQlFDnDGI6CnLOhhpvBhd   2020-12-04
# 3   spotify:album:0GMu98ZhwAoTqk1hzEMicE   2020-12-02
# 4   spotify:album:16TT0OKoyEgD22nj70WUEi   2020-12-03
# ..                                   ...          ...
# 94  spotify:album:0uSrWUaD2vkXZhzpXKOfaS   2020-11-17
# 95  spotify:album:10fSu9RLAJlasIup4ylHPM   2020-11-16
# 96  spotify:album:5VOW9zYV8KoErvgrLYqKR2   2020-11-20
# 97  spotify:album:4OC1SbVjw7X1L0l2OrpPPg   2020-11-20
# 98  spotify:album:38v3Ga4U869AXC0BKIzuXG   2020-11-18
#
#                                     available_markets  \
# 0   [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 1   [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 2   [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 3   [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 4   [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# ..                                                ...
# 94  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 95  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 96  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 97  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 98  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
#
#                                             image_url
# 0   https://i.scdn.co/image/ab67616d0000485179d6f4...
# 1   https://i.scdn.co/image/ab67616d0000485137a5a1...
# 2   https://i.scdn.co/image/ab67616d00004851ab3527...
# 3   https://i.scdn.co/image/ab67616d000048511d02e0...
# 4   https://i.scdn.co/image/ab67616d000048515c37a5...
# ..                                                ...
# 94  https://i.scdn.co/image/ab67616d00004851e357c7...
# 95  https://i.scdn.co/image/ab67616d000048513b9ae6...
# 96  https://i.scdn.co/image/ab67616d000048510a7af9...
# 97  https://i.scdn.co/image/ab67616d00004851887c63...
# 98  https://i.scdn.co/image/ab67616d00004851ffeeca...
#
# [99 rows x 9 columns]

# %% [markdown]
# ### Collecting 100 Songs By Year (Last 10 Years) - Done

# %%
# Notes:
#   Genres not available in the returned info here. 

def songs_by_year(years):
    track_name = []
    track_id = []
    track_uri = []
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    release_date = []
    popularity = []
    explicit = []
    available_markets = []
    preview_url = []
    image_url = []
    year_id = []


    for x in years:
        for i in range(0,100,50):
            track_results = sp.search(q=('year:'+x), type='track', limit=50,offset=i)
            for i, item in enumerate(track_results['tracks']['items']):
                track_name.append(item['name'])
                track_id.append(item['id'])
                track_uri.append(item['uri'])
                artist_name.append(item['artists'][0]['name'])
                artist_id.append(item['artists'][0]['id'])
                artist_uri.append(item['artists'][0]['uri'])
                album_name.append(item['album']['name'])
                album_id.append(item['album']['id'])
                album_uri.append(item['album']['uri'])
                release_date.append(item['album']['release_date'])
                popularity.append(item['popularity'])
                explicit.append(item['explicit'])
                available_markets.append(item['available_markets'])
                preview_url.append(item['preview_url'])
                image_url.append(item['album']['images'][2]['url'])
                year_id.append(x)
            
            
    top100_dataframe = pd.DataFrame({'track_name' : track_name,
                                'track_id' : track_id,
                                'track_uri' : track_uri,
                                'artist_name' : artist_name,
                                'artist_id' : artist_id,
                                'artist_uri' : artist_uri,
                                'album_name' : album_name,
                                'album_id' : album_id,
                                'album_uri' : album_uri,
                                'release_date' : release_date,
                                'popularity' : popularity,
                                'explicit' : explicit,
                                'available_markets' : available_markets,
                                'preview_url' : preview_url,
                                'image_url' : image_url,
                                'year_id' : year_id})
    
    return top100_dataframe

# %%
years = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

top_100_songs = songs_by_year(years)

top_100_songs.groupby('year_id')
top_100_songs.sort_values('popularity', ascending = False)

# %% [markdown]
# ### Information For A Single Track - Done

# %%
# Notes:
    # This can be used in a loop to pull and collect all the data for a track. 
    # This returns a dataframe with one line. When writing a loop, take that into consideration. 
    
def track_search(uri):
    track = sp.track(uri)
            
    track_dataframe = pd.DataFrame({'track_name' : [track['name']],
                                'track_id' : [track['id']],
                                'track_uri' : [track['uri']],
                                'artist_name' : [track['artists'][0]['name']],
                                'artist_id' : [track['artists'][0]['id']],
                                'artist_uri' : [track['artists'][0]['uri']],
                                'album_name' : [track['album']['name']],
                                'album_id' : [track['album']['id']],
                                'album_uri' : [track['album']['uri']],
                                'release_date' : [track['album']['release_date']],
                                'popularity' : [track['popularity']],
                                'explicit' : [track['explicit']],
                                'available_markets' : [track['available_markets']],
                                'preview_url' : [track['preview_url']],
                                'image_url' : [track['album']['images'][2]['url']]})
    
    return track_dataframe

# %%
uri = 'spotify:track:0Svkvt5I79wficMFgaqEQJ'
track_df = track_search(uri)
track_df
# Out:
#    track_name                track_id                             track_uri  \
# 0  El Scorcho  0Svkvt5I79wficMFgaqEQJ  spotify:track:0Svkvt5I79wficMFgaqEQJ
#
#   artist_name               artist_id                             artist_uri  \
# 0      Weezer  3jOstUTkEu2JkjvRdBA5Gu  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
#
#   album_name                album_id                             album_uri  \
# 0  Pinkerton  04xe676vyiTeYNXw15o9jT  spotify:album:04xe676vyiTeYNXw15o9jT
#
#   release_date  popularity  explicit available_markets preview_url  \
# 0   1996-09-24           0     False                []        None
#
#                                            image_url
# 0  https://i.scdn.co/image/ab67616d00004851baee44...

# %% [markdown]
# ### Information For One Album - Done

# %%
def album_search(uri):
    album = sp.album(uri)
            
    album_dataframe = pd.DataFrame({'artist_name' : [album['artists'][0]['name']],
                                'artist_id' : [album['artists'][0]['id']],
                                'artist_uri' : [album['artists'][0]['uri']],
                                'album_name' : [album['name']],
                                'album_id' : [album['id']],
                                'album_uri' : [album['uri']],
                                'release_date' : [album['release_date']],
                                'label' : album['label'],
                                'genres' : [album['genres']],
                                'popularity' : [album['popularity']],
                                'available_markets' : [album['available_markets']],
                                'image_url' : [album['images'][2]['url']]})
    
    return album_dataframe

# %%
uri = 'spotify:album:04xe676vyiTeYNXw15o9jT'
album_df = album_search(uri)
album_df
# Out:
#   artist_name               artist_id                             artist_uri  \
# 0      Weezer  3jOstUTkEu2JkjvRdBA5Gu  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
#
#   album_name                album_id                             album_uri  \
# 0  Pinkerton  04xe676vyiTeYNXw15o9jT  spotify:album:04xe676vyiTeYNXw15o9jT
#
#   release_date                  label genres  popularity available_markets  \
# 0   1996-09-24  Universal Music Group     []           0                []
#
#                                            image_url
# 0  https://i.scdn.co/image/ab67616d00004851baee44...

# %% [markdown]
# ### Getting Tracks For An Album - Needs Work

# %%
def album_tracks(uri):
    track_name = []
    track_id = []
    track_uri = []
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    
    album = sp.track(uri)

# %% [markdown]
# ### Albums For An Artist - Done

# %%
def artists_albums(input_uri):
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    release_date = []
    available_markets = []
    image_url = []

    results = sp.artist_albums(input_uri, album_type='album')

    while results:
        
        for i, item in enumerate(results['items']):
            artist_name.append(item['artists'][0]['name'])
            artist_id.append(item['artists'][0]['id'])
            artist_uri.append(item['artists'][0]['uri'])
            album_name.append(item['name'])
            album_id.append(item['id'])
            album_uri.append(item['uri'])
            release_date.append(item['release_date'])
            available_markets.append(item['available_markets'])
            image_url.append(item['images'][2]['url'])
            
        if results['next']:
            results = sp.next(results)
        else:
            results = None
        
    artist_albums_dataframe = pd.DataFrame({'artist_name' : artist_name,
                                'artist_id' : artist_id,
                                'artist_uri' : artist_uri,
                                'album_name' : album_name,
                                'album_id' : album_id,
                                'album_uri' : album_uri,
                                'release_date' : release_date,
                                'available_markets' : available_markets,
                                'image_url' : image_url})
    
    artist_albums_dataframe.groupby(['artist_name', 'album_name'])
    
    return artist_albums_dataframe

# %%
uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
artists_df = artists_albums(uri)
artists_df
# Out:
#    artist_name               artist_id                             artist_uri  \
# 0        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 1        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 2        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 3        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 4        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 5        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 6        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 7        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 8        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 9        Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 10       Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 11       Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 12       Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 13       Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
# 14       Birdy  2WX2uTcsvV5OnS0inACecP  spotify:artist:2WX2uTcsvV5OnS0inACecP
#
#                  album_name                album_id  \
# 0            Beautiful Lies  1UVggFtdVPqHy5WamYFu6w
# 1            Beautiful Lies  5wNnopxjgSKVvHTIcBpV8Q
# 2   Beautiful Lies (Deluxe)  2uNFpEVey5RsxzTdoDmjiz
# 3   Beautiful Lies (Deluxe)  5TxrdDAUkipqcb4zGnnwkz
# 4               Fire Within  0r94AFhRLvpfXvha7vx2dK
# 5               Fire Within  1JCe9MAwb1aE01UoAwCnOM
# 6      Fire Within (Deluxe)  7xvS6C6kW205wbu0fjwqyu
# 7      Fire Within (Deluxe)  24f6ycLAjcI8rNYfV6WZvS
# 8      Fire Within (Deluxe)  6ig2k0oiH2AXm8MugikskB
# 9            Live in London  55BQeeBdoCapsI5SZFA3IN
# 10                    Birdy  1RmWIBEicywaqVL5re4qbI
# 11                    Birdy  7j7ykLBxerILBLBc8AICJS
# 12                    Birdy  2dpWqqBl9Faf0Bfo8q4F5u
# 13                    Birdy  1WGjSVIw0TVfbp5KrOFiP0
# 14   Birdy (Deluxe Version)  3sGzkurA1fvEFqh73sWCVA
#
#                                album_uri release_date  \
# 0   spotify:album:1UVggFtdVPqHy5WamYFu6w   2016-03-25
# 1   spotify:album:5wNnopxjgSKVvHTIcBpV8Q   2016-03-25
# 2   spotify:album:2uNFpEVey5RsxzTdoDmjiz   2016-03-25
# 3   spotify:album:5TxrdDAUkipqcb4zGnnwkz   2016-03-25
# 4   spotify:album:0r94AFhRLvpfXvha7vx2dK   2013-09-16
# 5   spotify:album:1JCe9MAwb1aE01UoAwCnOM   2013-09-16
# 6   spotify:album:7xvS6C6kW205wbu0fjwqyu   2013-09-16
# 7   spotify:album:24f6ycLAjcI8rNYfV6WZvS   2013-09-16
# 8   spotify:album:6ig2k0oiH2AXm8MugikskB   2013-09-16
# 9   spotify:album:55BQeeBdoCapsI5SZFA3IN         2012
# 10  spotify:album:1RmWIBEicywaqVL5re4qbI   2011-11-19
# 11  spotify:album:7j7ykLBxerILBLBc8AICJS   2011-11-07
# 12  spotify:album:2dpWqqBl9Faf0Bfo8q4F5u   2011-11-07
# 13  spotify:album:1WGjSVIw0TVfbp5KrOFiP0   2011-11-04
# 14  spotify:album:3sGzkurA1fvEFqh73sWCVA   2011-11-04
#
#                                     available_markets  \
# 0   [AD, AE, AL, AR, AU, BA, BE, BG, BH, BO, BR, B...
# 1                                                [US]
# 2   [AD, AE, AL, AR, AU, BA, BE, BG, BH, BO, BR, B...
# 3                                        [AT, CH, DE]
# 4                                        [CA, ES, US]
# 5   [AD, AE, AL, AR, AU, BA, BG, BH, BO, BR, BY, C...
# 6                                                [JP]
# 7                                        [AT, CH, DE]
# 8   [AD, AE, AL, AR, BA, BE, BG, BH, BO, BR, BY, C...
# 9   [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 10                                           [CA, US]
# 11                                               [AU]
# 12                                               [GB]
# 13  [AL, AR, AT, BA, BE, BG, BO, BR, BY, CH, CL, C...
# 14  [AD, AE, AL, AR, AT, BA, BE, BG, BH, BO, BR, B...
#
#                                             image_url
# 0   https://i.scdn.co/image/ab67616d0000485155ff8d...
# 1   https://i.scdn.co/image/ab67616d00004851f67ea4...
# 2   https://i.scdn.co/image/ab67616d00004851921212...
# 3   https://i.scdn.co/image/ab67616d00004851b3b172...
# 4   https://i.scdn.co/image/ab67616d000048513feff1...
# 5   https://i.scdn.co/image/ab67616d00004851a64f80...
# 6   https://i.scdn.co/image/ab67616d00004851106164...
# 7   https://i.scdn.co/image/ab67616d0000485194d5b5...
# 8   https://i.scdn.co/image/ab67616d000048516cf816...
# 9   https://i.scdn.co/image/ab67616d00004851fd5ae5...
# 10  https://i.scdn.co/image/ab67616d00004851624df4...
# 11  https://i.scdn.co/image/ab67616d000048512ff207...
# 12  https://i.scdn.co/image/ab67616d000048516d1ed4...
# 13  https://i.scdn.co/image/ab67616d00004851cdebae...
# 14  https://i.scdn.co/image/ab67616d000048510d3e27...

# %% [markdown]
# ### Getting 100 Tracks For An Artist - Done

# %%
# Notes:
#    Can only retrieve by artist name here... not URI
#    Results can get muddy as other artists can be included. Not the best search. 
#       Could filter out results that do not match the artist name... This would resolve the above issue. 

def artist_songs(input_artist_name):
    track_name = []
    track_id = []
    track_uri = []
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    release_date = []
    popularity = []
    explicit = []
    available_markets = []
    preview_url = []
    image_url = []
    
    for i in range(0,100,20):
            artist_songs = sp.search(q=(input_artist_name), limit=20, offset=i)

            for i, item in enumerate(artist_songs['tracks']['items']):
                track_name.append(item['name'])
                track_id.append(item['id'])
                track_uri.append(item['uri'])
                artist_name.append(item['artists'][0]['name'])
                artist_id.append(item['artists'][0]['id'])
                artist_uri.append(item['artists'][0]['uri'])
                album_name.append(item['album']['name'])
                album_id.append(item['album']['id'])
                album_uri.append(item['album']['uri'])
                release_date.append(item['album']['release_date'])
                popularity.append(item['popularity'])
                explicit.append(item['explicit'])
                available_markets.append(item['available_markets'])
                preview_url.append(item['preview_url'])
                image_url.append(item['album']['images'][2]['url'])
        
    artist_songs_dataframe = pd.DataFrame({'track_name' : track_name,
                                'track_name' : track_name,
                                'track_id' : track_id,
                                'track_uri' : track_uri,
                                'artist_name' : artist_name,
                                'artist_id' : artist_id,
                                'artist_uri' : artist_uri,
                                'album_name' : album_name,
                                'album_id' : album_id,
                                'album_uri' : album_uri,
                                'release_date' : release_date,
                                'popularity' : popularity,
                                'explicit' : explicit,
                                'available_markets' : available_markets,
                                'preview_url' : preview_url,
                                'image_url' : image_url})
    
    return artist_songs_dataframe

# %%
input_artist_name = 'Radiohead'
artist_songs(input_artist_name)
# Out:
#                                   track_name                track_id  \
# 0                                      Creep  6b2oQwSGFkzsMtQruIWm2p
# 1                               Karma Police  3SVAN3BRByDmHOhKyIDxfC
# 2                               High And Dry  5jafMI8FLibnjkYTZ33m0c
# 3                               No Surprises  1bSpwPhAxZwlR2enJJsv7U
# 4                    Exit Music (For a Film)  4Na0siMtWOW9pJoWJ1Ponv
# ..                                       ...                     ...
# 95  Subterranean Homesick Alien - Remastered  0vgSQrQMEoa6VecE9Y5Dnk
# 96                     Let Down - Remastered  1CeC8kOYxUTCC2wHGtWROD
# 97                        Down Is The New Up  4Nckr2LBLkgNOdMadwNAxc
# 98                           True Love Waits  07XaOyTS5hyaWiUK1Bc3bR
# 99                 Karma Police - Remastered  70VjECXPkO7APS1bAj4wEN
#
#                                track_uri artist_name               artist_id  \
# 0   spotify:track:6b2oQwSGFkzsMtQruIWm2p   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 1   spotify:track:3SVAN3BRByDmHOhKyIDxfC   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 2   spotify:track:5jafMI8FLibnjkYTZ33m0c   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 3   spotify:track:1bSpwPhAxZwlR2enJJsv7U   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 4   spotify:track:4Na0siMtWOW9pJoWJ1Ponv   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# ..                                   ...         ...                     ...
# 95  spotify:track:0vgSQrQMEoa6VecE9Y5Dnk   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 96  spotify:track:1CeC8kOYxUTCC2wHGtWROD   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 97  spotify:track:4Nckr2LBLkgNOdMadwNAxc   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 98  spotify:track:07XaOyTS5hyaWiUK1Bc3bR   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
# 99  spotify:track:70VjECXPkO7APS1bAj4wEN   Radiohead  4Z8W4fKeB5YxbusRsdQVPb
#
#                                artist_uri                     album_name  \
# 0   spotify:artist:4Z8W4fKeB5YxbusRsdQVPb                    Pablo Honey
# 1   spotify:artist:4Z8W4fKeB5YxbusRsdQVPb                    OK Computer
# 2   spotify:artist:4Z8W4fKeB5YxbusRsdQVPb                      The Bends
# 3   spotify:artist:4Z8W4fKeB5YxbusRsdQVPb                    OK Computer
# 4   spotify:artist:4Z8W4fKeB5YxbusRsdQVPb                    OK Computer
# ..                                    ...                            ...
# 95  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb  OK Computer OKNOTOK 1997 2017
# 96  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb  OK Computer OKNOTOK 1997 2017
# 97  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb           In Rainbows (Disk 2)
# 98  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb             A Moon Shaped Pool
# 99  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb  OK Computer OKNOTOK 1997 2017
#
#                   album_id                             album_uri release_date  \
# 0   6400dnyeDyD2mIFHfkwHXN  spotify:album:6400dnyeDyD2mIFHfkwHXN   1993-02-22
# 1   7dxKtc08dYeRVHt3p9CZJn  spotify:album:7dxKtc08dYeRVHt3p9CZJn   1997-05-28
# 2   500FEaUzn8lN9zWFyZG5C2  spotify:album:500FEaUzn8lN9zWFyZG5C2   1995-03-28
# 3   7dxKtc08dYeRVHt3p9CZJn  spotify:album:7dxKtc08dYeRVHt3p9CZJn   1997-05-28
# 4   7dxKtc08dYeRVHt3p9CZJn  spotify:album:7dxKtc08dYeRVHt3p9CZJn   1997-05-28
# ..                     ...                                   ...          ...
# 95  0tzfI6NFJqcJkWb23R3lRZ  spotify:album:0tzfI6NFJqcJkWb23R3lRZ   2017-06-23
# 96  0tzfI6NFJqcJkWb23R3lRZ  spotify:album:0tzfI6NFJqcJkWb23R3lRZ   2017-06-23
# 97  6zTAW5oRuOmxJuUHhcQope  spotify:album:6zTAW5oRuOmxJuUHhcQope         2007
# 98  2ix8vWvvSp2Yo7rKMiWpkg  spotify:album:2ix8vWvvSp2Yo7rKMiWpkg   2016-05-08
# 99  0tzfI6NFJqcJkWb23R3lRZ  spotify:album:0tzfI6NFJqcJkWb23R3lRZ   2017-06-23
#
#     popularity  explicit                                  available_markets  \
# 0           81      True                                                 []
# 1           74     False                                                 []
# 2           71     False                                                 []
# 3           72     False                                                 []
# 4           67     False                                                 []
# ..         ...       ...                                                ...
# 95          37     False  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 96          37     False  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 97          35     False  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 98          35     False  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 99          37     False  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
#
#                                           preview_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  https://p.scdn.co/mp3-preview/8933bfc50726b099...
# 96  https://p.scdn.co/mp3-preview/422381a0d4ffd2b2...
# 97  https://p.scdn.co/mp3-preview/38a125e36bcd0534...
# 98  https://p.scdn.co/mp3-preview/0505b5634df5d474...
# 99  https://p.scdn.co/mp3-preview/e2303a68fd90eba9...
#
#                                             image_url
# 0   https://i.scdn.co/image/ab67616d000048512f85b6...
# 1   https://i.scdn.co/image/ab67616d00004851adb173...
# 2   https://i.scdn.co/image/ab67616d0000485122ca59...
# 3   https://i.scdn.co/image/ab67616d00004851adb173...
# 4   https://i.scdn.co/image/ab67616d00004851adb173...
# ..                                                ...
# 95  https://i.scdn.co/image/ab67616d000048518dabbb...
# 96  https://i.scdn.co/image/ab67616d000048518dabbb...
# 97  https://i.scdn.co/image/ab67616d000048514b88d5...
# 98  https://i.scdn.co/image/ab67616d0000485145643f...
# 99  https://i.scdn.co/image/ab67616d000048518dabbb...
#
# [100 rows x 15 columns]

# %% [markdown]
# ### Top Songs For An Artist - Done

# %%
def artist_top_songs(input_uri):
    track_name = []
    track_id = []
    track_uri = []
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    release_date = []
    popularity = []
    explicit = []
    available_markets = []
    preview_url = []
    image_url = []


    top_songs = sp.artist_top_tracks(input_uri)


    for i, item in enumerate(top_songs['tracks']):
        track_name.append(item['name'])
        track_id.append(item['id'])
        track_uri.append(item['uri'])
        artist_name.append(item['artists'][0]['name'])
        artist_id.append(item['artists'][0]['id'])
        artist_uri.append(item['artists'][0]['uri'])
        album_name.append(item['album']['name'])
        album_id.append(item['album']['id'])
        album_uri.append(item['album']['uri'])
        release_date.append(item['album']['release_date'])
        popularity.append(item['popularity'])
        explicit.append(item['explicit'])
        preview_url.append(item['preview_url'])
        image_url.append(item['album']['images'][2]['url'])
        
    top_songs_dataframe = pd.DataFrame({'track_name' : track_name,
                                'track_name' : track_name,
                                'track_id' : track_id,
                                'track_uri' : track_uri,
                                'artist_name' : artist_name,
                                'artist_id' : artist_id,
                                'artist_uri' : artist_uri,
                                'album_name' : album_name,
                                'album_id' : album_id,
                                'album_uri' : album_uri,
                                'release_date' : release_date,
                                'popularity' : popularity,
                                'explicit' : explicit,
                                'preview_url' : preview_url,
                                'image_url' : image_url})
    
    return top_songs_dataframe

# %%
urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'

artist_top_songs(urn)
# Out:
#                            track_name                track_id  \
# 0                   Island In The Sun  2MLHyLy5z5l5YRp7momlgw
# 1                     Say It Ain't So  6VoIBz0VhCyz7OdEoRYDiA
# 2                         Buddy Holly  3mwvKOyMmG77zZRunnxp9E
# 3                       Beverly Hills  1yKu2MhpwzDXXH2tzG6xoa
# 4                           Hash Pipe  2mPMFJvQ0v27gVqe5b6nDn
# 5           Undone - The Sweater Song  5WhtlIoxoZrMmuaWWEQhwV
# 6  Lost in the Woods - Weezer Version  227zkOoNpqRrzEPxvVRiF5
# 7                              Africa  3ZPKocroJIcnHGcnJVlLKD
# 8                    My Name Is Jonas  4nzyOwogJuWn1s6QuGFZ6w
# 9                                Hero  4Fj6KslSYYQ1kAbafiKoz0
#
#                               track_uri artist_name               artist_id  \
# 0  spotify:track:2MLHyLy5z5l5YRp7momlgw      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 1  spotify:track:6VoIBz0VhCyz7OdEoRYDiA      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 2  spotify:track:3mwvKOyMmG77zZRunnxp9E      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 3  spotify:track:1yKu2MhpwzDXXH2tzG6xoa      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 4  spotify:track:2mPMFJvQ0v27gVqe5b6nDn      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 5  spotify:track:5WhtlIoxoZrMmuaWWEQhwV      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 6  spotify:track:227zkOoNpqRrzEPxvVRiF5      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 7  spotify:track:3ZPKocroJIcnHGcnJVlLKD      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 8  spotify:track:4nzyOwogJuWn1s6QuGFZ6w      Weezer  3jOstUTkEu2JkjvRdBA5Gu
# 9  spotify:track:4Fj6KslSYYQ1kAbafiKoz0      Weezer  3jOstUTkEu2JkjvRdBA5Gu
#
#                               artist_uri  \
# 0  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 1  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 2  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 3  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 4  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 5  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 6  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 7  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 8  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
# 9  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu
#
#                                           album_name                album_id  \
# 0                               Weezer (Green Album)  2OBSz5Nlto0Q5CtYPzPY7c
# 1                                             Weezer  1xpGyKyV26uPstk1Elgp9Q
# 2                                             Weezer  1xpGyKyV26uPstk1Elgp9Q
# 3                                       Make Believe  4D8A8M0NJjEdQhusawyeDz
# 4                               Weezer (Green Album)  2OBSz5Nlto0Q5CtYPzPY7c
# 5                                             Weezer  1xpGyKyV26uPstk1Elgp9Q
# 6  Frozen 2 (Original Motion Picture Soundtrack/D...  4M07HWIlZr7zoXoxDHR5mz
# 7                                Weezer (Teal Album)  65sHj9PvsbyD0uugGHjueN
# 8                                             Weezer  1xpGyKyV26uPstk1Elgp9Q
# 9                                               Hero  4FrRRR86MYCjoLFV8dgnm5
#
#                               album_uri release_date  popularity  explicit  \
# 0  spotify:album:2OBSz5Nlto0Q5CtYPzPY7c   2001-05-15          76     False
# 1  spotify:album:1xpGyKyV26uPstk1Elgp9Q   1994-05-10          73     False
# 2  spotify:album:1xpGyKyV26uPstk1Elgp9Q   1994-05-10          71     False
# 3  spotify:album:4D8A8M0NJjEdQhusawyeDz   2005-05-10          70     False
# 4  spotify:album:2OBSz5Nlto0Q5CtYPzPY7c   2001-05-15          65     False
# 5  spotify:album:1xpGyKyV26uPstk1Elgp9Q   1994-05-10          63     False
# 6  spotify:album:4M07HWIlZr7zoXoxDHR5mz   2019-11-15          63     False
# 7  spotify:album:65sHj9PvsbyD0uugGHjueN   2019-01-24          61     False
# 8  spotify:album:1xpGyKyV26uPstk1Elgp9Q   1994-05-10          60     False
# 9  spotify:album:4FrRRR86MYCjoLFV8dgnm5   2020-05-06          59     False
#
#                                          preview_url  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7  https://p.scdn.co/mp3-preview/fd50e613eafb6f28...
# 8                                               None
# 9  https://p.scdn.co/mp3-preview/b80c8433159195f6...
#
#                                            image_url
# 0  https://i.scdn.co/image/ab67616d000048511e0dc5...
# 1  https://i.scdn.co/image/ab67616d00004851345536...
# 2  https://i.scdn.co/image/ab67616d00004851345536...
# 3  https://i.scdn.co/image/ab67616d00004851a9def6...
# 4  https://i.scdn.co/image/ab67616d000048511e0dc5...
# 5  https://i.scdn.co/image/ab67616d00004851345536...
# 6  https://i.scdn.co/image/ab67616d000048516ff59d...
# 7  https://i.scdn.co/image/ab67616d0000485123473d...
# 8  https://i.scdn.co/image/ab67616d00004851345536...
# 9  https://i.scdn.co/image/ab67616d00004851a2084a...

# %% [markdown]
# ### Finding Related Artists - Done

# %%
def related_artists(input_uri):
    artist_name = []
    artist_id = []
    artist_uri = []
    followers = []
    genres = []
    image_url = []

    related = sp.artist_related_artists(input_uri)

    for i, item in enumerate(related['artists']):
        artist_name.append(item['name'])
        artist_id.append(item['id'])
        artist_uri.append(item['uri'])
        followers.append(item['followers']['total'])
        genres.append(item['genres'])
        image_url.append(item['images'][2]['url'])
        
    related_artists_dataframe = pd.DataFrame({'artist_name': artist_name, 
                                              'artist_id' : artist_id,
                                              'artist_uri' : artist_uri,
                                              'followers' : followers,
                                              'genres' : genres,
                                              'image_url' : image_url})
    
    return related_artists_dataframe

# %%
weezer_uri = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'
weezer_related = related_artists(weezer_uri)
weezer_related.head()
# Out:
#                                       artist_name               artist_id  \
# 0  The Presidents Of The United States Of America  1lZvg4fNAqHoj6I9N8naBM
# 1                                            Cake  6A43Djmhbe9100UwnI7epV
# 2                                       Everclear  694QW15WkebjcrWgQHzRYF
# 3                                 Third Eye Blind  6TcnmlCSxihzWOQJ8k0rNS
# 4                                 Jimmy Eat World  3Ayl7mCk0nScecqOzvNp6s
#
#                               artist_uri  followers  \
# 0  spotify:artist:1lZvg4fNAqHoj6I9N8naBM     388622
# 1  spotify:artist:6A43Djmhbe9100UwnI7epV     800440
# 2  spotify:artist:694QW15WkebjcrWgQHzRYF     614548
# 3  spotify:artist:6TcnmlCSxihzWOQJ8k0rNS    1046542
# 4  spotify:artist:3Ayl7mCk0nScecqOzvNp6s    1094067
#
#                                               genres  \
# 0  [alternative metal, alternative rock, grunge, ...
# 1  [alternative rock, modern rock, pop rock, rock...
# 2  [alternative metal, alternative rock, permanen...
# 3  [alternative rock, neo mellow, pop rock, post-...
# 4  [emo, modern power pop, modern rock, pop punk,...
#
#                                            image_url
# 0  https://i.scdn.co/image/d8ca1f9cedbdcf75228cac...
# 1  https://i.scdn.co/image/1dac9f82d940e5f9f471ed...
# 2  https://i.scdn.co/image/fedf9c83b9bbbf2e99c395...
# 3  https://i.scdn.co/image/6ede981407c36dae70baf8...
# 4  https://i.scdn.co/image/ea3ebf2e08dbf8181187e1...

# %% [markdown]
# ### Searching Markets - Done

# %%
def searching_markets(input_track_name):
    input_markets = ['AD', 'AE', 'AL', 'AR', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CL',
    'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR',
    'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ',
    'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL',
    'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA',
    'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'UY', 'VN', 'XK', 'ZA']
    
    track_name = []
    track_id = []
    track_uri = []
    artist_name = []
    artist_id = []
    artist_uri = []
    album_name = []
    album_id = []
    album_uri = []
    release_date = []
    popularity = []
    explicit = []
    available_markets = []
    preview_url = []
    image_url = []
    search_market = []
    
    for market in input_markets:
            results = sp.search_markets(q=input_track_name, markets=[market])
            
            market_result = results[market]

            for i, item in enumerate(market_result['tracks']['items']):
                track_name.append(item['name'])
                track_id.append(item['id'])
                track_uri.append(item['uri'])
                artist_name.append(item['artists'][0]['name'])
                artist_id.append(item['artists'][0]['id'])
                artist_uri.append(item['artists'][0]['uri'])
                album_name.append(item['album']['name'])
                album_id.append(item['album']['id'])
                album_uri.append(item['album']['uri'])
                release_date.append(item['album']['release_date'])
                popularity.append(item['popularity'])
                explicit.append(item['explicit'])
                available_markets.append(item['available_markets'])
                preview_url.append(item['preview_url'])
                image_url.append(item['album']['images'][2]['url'])
                search_market.append(market)
        
    markets_dataframe = pd.DataFrame({'track_name' : track_name,
                                'track_name' : track_name,
                                'track_id' : track_id,
                                'track_uri' : track_uri,
                                'artist_name' : artist_name,
                                'artist_id' : artist_id,
                                'artist_uri' : artist_uri,
                                'album_name' : album_name,
                                'album_id' : album_id,
                                'album_uri' : album_uri,
                                'release_date' : release_date,
                                'popularity' : popularity,
                                'explicit' : explicit,
                                'available_markets' : available_markets,
                                'preview_url' : preview_url,
                                'image_url' : image_url,
                                'search_market' : search_market})
    
    return markets_dataframe

# %%
searching_markets('wap')
# Out:
# /Users/jonathanschlosser/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py:566: UserWarning: Searching multiple markets is an experimental feature. Please be aware that this method's inputs and outputs can change in the future.
#   UserWarning,
# /Users/jonathanschlosser/opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py:576: UserWarning: Searching multiple markets is poorly performing.
#   UserWarning,
#                                    track_name                track_id  \
# 0             WAP (feat. Megan Thee Stallion)  4Oun2ylbjFKMPTiaSbbCih
# 1                                         WAP  4fNTitdIzXrrMMOQ29rMgB
# 2                              Wapo Traketero  5ctNuquTVDsfMb9jKzsYu0
# 3                                         WAP  3qXAxOQWV1Im5EwHOjkyQX
# 4    Wapo Traketero - El Paredon Live Session  1yRYfkGflSPUPodOyB1RTA
# ..                                        ...                     ...
# 875                                       WAP  2sf48AOJdvX0BZKrMKo0AC
# 876                       WAP (Metal Version)  6pKa9QAHeJsVGJvPG2bE47
# 877  Wapo Traketero - El Paredon Live Session  1yRYfkGflSPUPodOyB1RTA
# 878                                       WAP  4X4fLd1TOqmll9KpOR5CcA
# 879                                    Wappie  1WlZ6kEPZWC8DnOcbl2gQm
#
#                                 track_uri             artist_name  \
# 0    spotify:track:4Oun2ylbjFKMPTiaSbbCih                 Cardi B
# 1    spotify:track:4fNTitdIzXrrMMOQ29rMgB                  Koosen
# 2    spotify:track:5ctNuquTVDsfMb9jKzsYu0            Nicki Nicole
# 3    spotify:track:3qXAxOQWV1Im5EwHOjkyQX  Vitamin String Quartet
# 4    spotify:track:1yRYfkGflSPUPodOyB1RTA            Nicki Nicole
# ..                                    ...                     ...
# 875  spotify:track:2sf48AOJdvX0BZKrMKo0AC             Qveen Herby
# 876  spotify:track:6pKa9QAHeJsVGJvPG2bE47                     Leo
# 877  spotify:track:1yRYfkGflSPUPodOyB1RTA            Nicki Nicole
# 878  spotify:track:4X4fLd1TOqmll9KpOR5CcA                 Lardi B
# 879  spotify:track:1WlZ6kEPZWC8DnOcbl2gQm                Frankuno
#
#                   artist_id                             artist_uri  \
# 0    4kYSro6naA4h99UJvo89HB  spotify:artist:4kYSro6naA4h99UJvo89HB
# 1    12nEr6QOfSKkiTXjEp8tBB  spotify:artist:12nEr6QOfSKkiTXjEp8tBB
# 2    2UZIAOlrnyZmyzt1nuXr9y  spotify:artist:2UZIAOlrnyZmyzt1nuXr9y
# 3    6MERXsiRbur2oJZFgYRDKz  spotify:artist:6MERXsiRbur2oJZFgYRDKz
# 4    2UZIAOlrnyZmyzt1nuXr9y  spotify:artist:2UZIAOlrnyZmyzt1nuXr9y
# ..                      ...                                    ...
# 875  4o4tLTIJ3eWMFerz73atcT  spotify:artist:4o4tLTIJ3eWMFerz73atcT
# 876  5KWOCu1saEHAhPiLKlOLIy  spotify:artist:5KWOCu1saEHAhPiLKlOLIy
# 877  2UZIAOlrnyZmyzt1nuXr9y  spotify:artist:2UZIAOlrnyZmyzt1nuXr9y
# 878  0FYAhaPtecgnKeVGXF47BT  spotify:artist:0FYAhaPtecgnKeVGXF47BT
# 879  4bo1uuBUYULyHx56bC45MK  spotify:artist:4bo1uuBUYULyHx56bC45MK
#
#                                    album_name                album_id  \
# 0             WAP (feat. Megan Thee Stallion)  2ogiazbrNEx0kQHGl5ZBTQ
# 1                                         WAP  5CFALzwsrZnnT38yuOLrDb
# 2                              Wapo Traketero  0HvHR0nVBzvwkzsIMHDRoZ
# 3       VSQ Performs the Hits of 2020, Vol. 2  6Y1qMU0XXnnAcBGlAGuOPJ
# 4    Wapo Traketero (El Paredon Live Session)  4zSCfICdo6GEMuEDLDs0js
# ..                                        ...                     ...
# 875                                       WAP  7eTwU0p8fRQhJ7qFMNIcXq
# 876                       WAP (Metal Version)  3khWK2uhzxqqwjoEfUOx94
# 877  Wapo Traketero (El Paredon Live Session)  4zSCfICdo6GEMuEDLDs0js
# 878                                       WAP  6709Wy6Erz0GRbAnC7IyaR
# 879                                    Wappie  1QzTsFzSQT2BdImissgeuW
#
#                                 album_uri release_date  popularity  explicit  \
# 0    spotify:album:2ogiazbrNEx0kQHGl5ZBTQ   2020-08-07          95      True
# 1    spotify:album:5CFALzwsrZnnT38yuOLrDb   2020-12-04          10      True
# 2    spotify:album:0HvHR0nVBzvwkzsIMHDRoZ   2019-04-26          64     False
# 3    spotify:album:6Y1qMU0XXnnAcBGlAGuOPJ   2020-12-04           1     False
# 4    spotify:album:4zSCfICdo6GEMuEDLDs0js   2019-10-22          51     False
# ..                                    ...          ...         ...       ...
# 875  spotify:album:7eTwU0p8fRQhJ7qFMNIcXq   2020-08-20          46      True
# 876  spotify:album:3khWK2uhzxqqwjoEfUOx94   2020-09-25          50      True
# 877  spotify:album:4zSCfICdo6GEMuEDLDs0js   2019-10-22          51     False
# 878  spotify:album:6709Wy6Erz0GRbAnC7IyaR   2020-08-18          41     False
# 879  spotify:album:1QzTsFzSQT2BdImissgeuW   2020-08-31          46     False
#
#     available_markets                                        preview_url  \
# 0                  []  https://p.scdn.co/mp3-preview/1ca9e7769467092f...
# 1                  []  https://p.scdn.co/mp3-preview/59e544a5ec534e96...
# 2                  []  https://p.scdn.co/mp3-preview/77252ee3c2364fa1...
# 3                  []  https://p.scdn.co/mp3-preview/b0ccc4c54dcb029e...
# 4                  []  https://p.scdn.co/mp3-preview/b0b041a8887eba7d...
# ..                ...                                                ...
# 875                []  https://p.scdn.co/mp3-preview/37700576f58eb93f...
# 876                []  https://p.scdn.co/mp3-preview/b9b71388fc50bac1...
# 877                []  https://p.scdn.co/mp3-preview/b0b041a8887eba7d...
# 878                []  https://p.scdn.co/mp3-preview/0cc02f09724aa26d...
# 879                []  https://p.scdn.co/mp3-preview/4916719b2ba140d6...
#
#                                              image_url search_market
# 0    https://i.scdn.co/image/ab67616d00004851c450c8...            AD
# 1    https://i.scdn.co/image/ab67616d00004851fb5224...            AD
# 2    https://i.scdn.co/image/ab67616d0000485173c4c5...            AD
# 3    https://i.scdn.co/image/ab67616d00004851d473b5...            AD
# 4    https://i.scdn.co/image/ab67616d0000485144cf8d...            AD
# ..                                                 ...           ...
# 875  https://i.scdn.co/image/ab67616d00004851190d3d...            ZA
# 876  https://i.scdn.co/image/ab67616d00004851ea80bc...            ZA
# 877  https://i.scdn.co/image/ab67616d0000485144cf8d...            ZA
# 878  https://i.scdn.co/image/ab67616d00004851e0b541...            ZA
# 879  https://i.scdn.co/image/ab67616d000048515e7075...            ZA
#
# [880 rows x 16 columns]

# %% [markdown]
# ### Audio Features Of A Track

# %%
# Notes:
    # This can be used in a loop to pull and collect all the data for a track. 
    # This returns a dataframe with one line. When writing a loop, take that into consideration. 
    
def audio_features(uri):
    track = sp.audio_features(uri)
            
    audio_features_dataframe = pd.DataFrame({'track_id' : [track[0]['id']],
                                'track_uri' : [track[0]['uri']],
                                'danceability' : [track[0]['danceability']],
                                'energy' : [track[0]['energy']],
                                'key' : [track[0]['key']],
                                'loudness' : [track[0]['loudness']],
                                'speechiness' : [track[0]['speechiness']],
                                'acousticness' : [track[0]['acousticness']],
                                'instrumentalness' : [track[0]['instrumentalness']],
                                'liveness' : [track[0]['liveness']],
                                'valence' : [track[0]['valence']],
                                'tempo' : [track[0]['tempo']],
                                'duration_ms' : [track[0]['duration_ms']],
                                'time_signature' : [track[0]['time_signature']]})
    
    return audio_features_dataframe

# %%
uri = 'spotify:track:0Svkvt5I79wficMFgaqEQJ'
af_df = audio_features(uri)
af_df
# Out:
#                  track_id                             track_uri  danceability  \
# 0  0Svkvt5I79wficMFgaqEQJ  spotify:track:0Svkvt5I79wficMFgaqEQJ         0.478
#
#    energy  key  loudness  speechiness  acousticness  instrumentalness  \
# 0   0.708    1    -5.021       0.0623        0.0556                 0
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0    0.0958    0.656  148.051       243531               4

# %% [markdown]
# ### Just For Reference

# %% [markdown]
# #### Displaying Images - Just for references

# %%
IFrame(track_dataframe['image_url'][3], width=500, height=500)

# %% [markdown]
# #### Playable Previews

# %%
url = 'https://p.scdn.co/mp3-preview/37700576f58eb93f8e2f4469eafe7725635f9867?cid=a9915d84a306475b862d512c14ba62a6'
# Need to use the Preview URL (preview_url)

IFrame(url, width=300, height=50)
